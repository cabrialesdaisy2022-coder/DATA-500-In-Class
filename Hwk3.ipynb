# %% [markdown]
# # Instructions
#
# - This homework assignment is worth **55** points.
# - Please strive for clarity and organization.
# - **AI Usage**:
#    - AI use is strictly **prohibited** for conceptual exercises.
#    - For applied (Python) exercises, you may only use AI for **debugging**. Do not use AI to generate answers.
# - **Due Date: September 25, 2026, by 11:59 PM.**

# %% [markdown]
# # Exercise 1
#
# In this exercise, we will keep practing `groupby`.
#
# ### Exercise 1(a) (2 points)
#
# Load the `pandas` library.

# %% [markdown]
# ### Exercise 1(b) (2 points)
#
# Read the `user.csv` data file and create a data frame called `users`. Notice that `|` is the data delimeter. Also, assign `user_id` as the index of the data frame.

# %% [markdown]
# ### Exercise 1(c) (2 points)
#
# Report the mean `age` per `occupation`.

# %% [markdown]
# ### Exercise 1(d) (5 points)
#
# Report the `gender` ratio per `occupation`.

# %% [markdown]
# ### Exercise 1(e) (3 points)
#
# For each `occupation`, report the minimum and maximum ages.

# %% [markdown]
# ### Exercise 1(f) (3 points)
#
# Report the mean `age` for each combination of `occupation` and `gender`.

# %% [markdown]
# # Exercise 2 (4 points)
#
# You are given a list of numeric strings. Convert the list into a list of integers and calculate the sum of the numbers.
#
# ```
# numeric_strings = ['1', '2', '3', '4', '5']
# ```

# %% [markdown]
# # Exercise 3 (4 points)
#
# You are given a list of numbers. Write a Python program to find the average of all odd numbers in the list.
#
# ```
# numbers = [5, 12, 3, 8, 7, 9, 10, 4, 15]
# ```

# %% [markdown]
# # Exercise 4
#
# In this exercise, we will keep practicing standard task with `pandas` data frames.
#
# ### Exercise 4(a) (3 points)
#
# Using the below code, create a data frame called `df` as follows:
#
# ```
# import pandas as pd
# import numpy as np
#
# df = pd.DataFrame({'Age': [25, np.nan, 35, 50, np.nan, 40],
#                   'Income': [50000, 62000, np.nan, 54000, 48000, np.nan],
#                   'Gender': ['Male', np.nan, 'Female', 'Male', 'Male', np.nan],
#                   'Purchased': ['Yes', 'No', 'Yes', np.nan, 'No', 'Yes']
#                   })
# ```

# %% [markdown]
# ### Exercise 4(b) (3 points)
#
# Report the percentage of missing data in each column of `df`.

# %% [markdown]
# ### Exercise 4(c) (5 points)
#
# Fill missing values in the numerical columns with the median of the respective columns.

# %% [markdown]
# ### Exercise 4(d) (5 points)
#
# Fill missing values in the categorical columns with the mode of the respective columns.

# %% [markdown]
# # Exercise 5 (2 points)
#
# **Multiple Choice:** According to Chapter 2, which of the following best describes an algorithm with $O(n \log n)$ time complexity, along with the representative example given in the text?
#
# (A) Constant time; a dictionary lookup
#
# (B) Log-linear time; efficient sorting algorithms such as merge sort or Timsort
#
# (C) Quadratic time; naive pairwise comparisons
#
# (D) Exponential time; brute-force subset enumeration
#
# (E) None of the above

# %% [markdown]
# *Your answer:*

# %% [markdown]
# # Exercise 6 (4 points)
#
# **Free Response:** Chapter 2 states that "premature optimization is the root of all evil," but clarifies that Knuth was not opposed to optimization itself.
#
# In your own words, explain:
#
# 1. The two conditions that Chapter 2 says should justify optimizing code.
# 2. Why optimizing code that already meets its performance requirement can actually be harmful rather than simply neutral.

# %% [markdown]
# *Your answer:*

# %% [markdown]
# # Exercise 7 (8 points)
#
# Chapter 2 introduces two ways to compute the mode (the most frequent value) of a list of integers: a pure-Python loop (`mode_using_loop`) and an implementation that delegates the counting step to `collections.Counter` (`mode_using_counter`).
#
# - Implement both functions exactly as described in Chapter 2.
# - Using `numpy`, generate an array of 100,000 random integers between 1 and 1,000 (inclusive) called `random_integers`.
# - Use the `timeit` module to time each function over 5 repetitions (`number=5`), storing the results in `loop_time` and `counter_time`, respectively.
# - Print both timing results, along with a statement indicating which implementation was faster.
#
# *Note: exact timings will vary depending on your machine, but `mode_using_counter` should be faster.*
